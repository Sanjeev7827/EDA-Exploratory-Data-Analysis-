# %% [markdown]
# Q.1-> What was the Most Preferred Payment Method ?
# Q.2-> Which one was the Most Selling Product
# By Quantity
# By Revenue
# Q.3-> Which City had maximum revenue, or, Which Manager earned maximum revenue ?
# Q.4-> Show the Date wise revenue.
# Q.5-> What was the Average Revenue ?
# Q.6-> What was the Average Revenue of November & December month ?
# Q.7-> What was the  Standard Deviation of Revenue and Quantity ?
# Q.8-> What was the Variance of Revenue and Quantity ?
# Q.9-> Was the revenue increasing or decreasing over the time?
# Q.10-> What was the Average 'Quantity Sold' & 'Average Revenue' for each product ?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"D:\Datasets(Github)\Restaurant Datset.csv")

# %%
df
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452   11/7/2022               Fries   3.49    573.07       Online
# 1       10453   11/7/2022           Beverages   2.95    745.76       Online
# 2       10454   11/7/2022       Sides & Other   4.99    200.40     In-store
# 3       10455   11/8/2022             Burgers  12.99    569.67     In-store
# 4       10456   11/8/2022  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  12/28/2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  12/29/2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  12/29/2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  12/29/2022               Fries   3.49    630.37   Drive-thru
# 253     10713  12/29/2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City
# ...

# %% [markdown]
#  # Q.1. What was the Most Preferred Payment Method ?

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
#  Credit Card    120
#  Cash            76
#  Gift Card       58
# Name: count, dtype: int64

# %%
sns.countplot(x='Payment Method',data=df,palette='inferno')
plt.legend(['Cash','Credit Card','Gift Card'])
plt.xlabel('Payment Method',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()

# %% [markdown]
#  # Q.2. Which one was the Most Selling Product
#  # a.By Quantity
#  # b.By Revenue

# %%
df.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452  11/7/2022               Fries   3.49    573.07       Online
# 1     10453  11/7/2022           Beverages   2.95    745.76       Online
# 2     10454  11/7/2022       Sides & Other   4.99    200.40     In-store
# 3     10455  11/8/2022             Burgers  12.99    569.67     In-store
# 4     10456  11/8/2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method        Manager    City
# 0      Gift Card    Tom Jackson  London
# 1      Gift Card    Pablo Perez  Madrid
# 2      Gift Card     Joao Silva  Lisbon
# 3    Credit Card  Walter Muller  Berlin
# 4    Credit Card  Walter Muller  Berlin

# %%
df.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34983.14
# Fries                 32034.34
# Burgers               29022.31
# Chicken Sandwiches    11135.92
# Sides & Other          9819.60
# Name: Quantity, dtype: float64

# %%
df.groupby('Product')['Quantity'].sum().plot(kind='bar',color='r')
plt.xticks(rotation=50)
plt.legend()
plt.title('Most Selling Product by Quantity',fontsize=15)
plt.xlabel('Products',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()

# %%
df['Revenue']=df['Price']*df['Quantity']

# %%
df
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452   11/7/2022               Fries   3.49    573.07       Online
# 1       10453   11/7/2022           Beverages   2.95    745.76       Online
# 2       10454   11/7/2022       Sides & Other   4.99    200.40     In-store
# 3       10455   11/8/2022             Burgers  12.99    569.67     In-store
# 4       10456   11/8/2022  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  12/28/2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  12/29/2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  12/29/2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  12/29/2022               Fries   3.49    630.37   Drive-thru
# 253     10713  12/29/2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City    Revenue
# ...

# %%
df.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Product
# Burgers               376999.8069
# Fries                 125674.2903
# Chicken Sandwiches    114641.6950
# Beverages             103200.2630
# Sides & Other          48999.8040
# Name: Revenue, dtype: float64

# %%
df.groupby('Product')['Revenue'].sum().plot(kind='bar',color='c')
plt.xticks(rotation=50)
plt.legend()
plt.title('Most Selling Product by Revenue',fontsize=15)
plt.xlabel('Products',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()

# %% [markdown]
#  # Q.3. Which City had maximum revenue, or, Which Manager earned maximum revenue ?

# %%
df.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452  11/7/2022               Fries   3.49    573.07       Online
# 1     10453  11/7/2022           Beverages   2.95    745.76       Online
# 2     10454  11/7/2022       Sides & Other   4.99    200.40     In-store
# 3     10455  11/8/2022             Burgers  12.99    569.67     In-store
# 4     10456  11/8/2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method        Manager    City    Revenue
# 0      Gift Card    Tom Jackson  London  2000.0143
# 1      Gift Card    Pablo Perez  Madrid  2199.9920
# 2      Gift Card     Joao Silva  Lisbon   999.9960
# 3    Credit Card  Walter Muller  Berlin  7400.0133
# 4    Credit Card  Walter Muller  Berlin  2000.0495

# %%
df.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    241714.1157
# London    211201.0406
# Madrid    136200.2665
# Berlin    100600.1313
# Paris      79800.3051
# Name: Revenue, dtype: float64

# %%
df.groupby('City')['Revenue'].sum().plot(kind='bar',color='y')
plt.xticks(rotation=50)
plt.legend()
plt.title('Most Revenue Generate by City',fontsize=15)
plt.xlabel('City',fontsize=15)
plt.ylabel('Count(US $)',fontsize=15)
plt.show()

# %%
df.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Manager
# Joao Silva       241714.1157
# Tom Jackson      211201.0406
# Pablo Perez      136200.2665
# Walter Muller    100600.1313
# Remy Monet        79800.3051
# Name: Revenue, dtype: float64

# %%
df.groupby('Manager')['Revenue'].sum().plot(kind='bar',color='m')
plt.xticks(rotation=50)
plt.legend()
plt.title('Most Revenue Generate by City',fontsize=15)
plt.xlabel('Manager',fontsize=15)
plt.ylabel('Count(US $)',fontsize=15)
plt.show()

# %% [markdown]
# # Q.4. Show the Date wise revenue.

# %%
df.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452  11/7/2022               Fries   3.49    573.07       Online
# 1     10453  11/7/2022           Beverages   2.95    745.76       Online
# 2     10454  11/7/2022       Sides & Other   4.99    200.40     In-store
# 3     10455  11/8/2022             Burgers  12.99    569.67     In-store
# 4     10456  11/8/2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method        Manager    City    Revenue
# 0      Gift Card    Tom Jackson  London  2000.0143
# 1      Gift Card    Pablo Perez  Madrid  2199.9920
# 2      Gift Card     Joao Silva  Lisbon   999.9960
# 3    Credit Card  Walter Muller  Berlin  7400.0133
# 4    Credit Card  Walter Muller  Berlin  2000.0495

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.sort_values(by='Date')
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries   3.49    573.07       Online
# 1       10453 2022-11-07           Beverages   2.95    745.76       Online
# 2       10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3       10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4       10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 246     10706 2022-12-28  Chicken Sandwiches   9.95    301.51   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712 2022-12-29               Fries   3.49    630.37   Drive-thru
# 250     10710 2022-12-29             Burgers  12.99    754.43   Drive-thru
# 253     10713 2022-12-29           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City    Revenue
# ...

# %%
df_new=df.groupby('Date')['Revenue'].sum().reset_index()

# %%
df_new.head()
# Out:
#         Date     Revenue
# 0 2022-11-07   5200.0023
# 1 2022-11-08  12400.0731
# 2 2022-11-09  14200.0386
# 3 2022-11-10  13200.0426
# 4 2022-11-11  14400.0156

# %%
df_new[df_new['Revenue']==27674.4512]
# Out:
#         Date     Revenue
# 6 2022-11-13  27674.4512

# %% [markdown]
# # Q.5. What was the Average Revenue ?

# %%
round(df['Revenue'].mean())
# Out:
# 3030

# %% [markdown]
# # Q.6. What was the Average Revenue of November & December month ?

# %%
df['month']=df['Date'].dt.month

# %%
df[(df['month']==11) | (df['month']==12)]['Revenue'].mean()
# Out:
# 3029.589996850394

# %% [markdown]
# # Q.7. What was the  Standard Deviation of Revenue and Quantity ?

# %%
df['Revenue'].std()
# Out:
# 2420.11837804107

# %%
df['Quantity'].std()
# Out:
# 214.88869921528874

# %% [markdown]
# # Q.8.What was the Variance of Revenue and Quantity ?

# %%
df['Revenue'].var()
# Out:
# 5856972.963732139

# %%
df['Quantity'].var()
# Out:
# 46177.153050438836

# %% [markdown]
# # Q.9. Was the revenue increasing or decreasing over the time?

# %%
df.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49    573.07       Online
# 1     10453 2022-11-07           Beverages   2.95    745.76       Online
# 2     10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3     10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method        Manager    City    Revenue  month
# 0      Gift Card    Tom Jackson  London  2000.0143     11
# 1      Gift Card    Pablo Perez  Madrid  2199.9920     11
# 2      Gift Card     Joao Silva  Lisbon   999.9960     11
# 3    Credit Card  Walter Muller  Berlin  7400.0133     11
# 4    Credit Card  Walter Muller  Berlin  2000.0495     11

# %%
df['day']=df['Date'].dt.day

# %%
df
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries   3.49    573.07       Online
# 1       10453 2022-11-07           Beverages   2.95    745.76       Online
# 2       10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3       10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4       10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other   4.99    200.40   Drive-thru
# 250     10710 2022-12-29             Burgers  12.99    754.43   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712 2022-12-29               Fries   3.49    630.37   Drive-thru
# 253     10713 2022-12-29           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City    Revenue  month  day
# ...

# %%
df['day']
# Out:
# 0       7
# 1       7
# 2       7
# 3       8
# 4       8
#        ..
# 249    28
# 250    29
# 251    29
# 252    29
# 253    29
# Name: day, Length: 254, dtype: int32

# %%
df.groupby(['month','day'])['Revenue'].sum().reset_index()
# Out:
#     month  day     Revenue
# 0      11    7   5200.0023
# 1      11    8  12400.0731
# 2      11    9  14200.0386
# 3      11   10  13200.0426
# 4      11   11  14400.0156
# 5      11   12  14000.0535
# 6      11   13  27674.4512
# 7      11   14  17839.3445
# 8      11   15  13600.0305
# 9      11   16  13600.0305
# 10     11   17  14000.0535
# 11     11   18  14400.1114
# 12     11   19  14000.0194
# 13     11   20   8200.0466
# 14     11   21  14000.0838
# 15     11   22  13599.9918
# 16     11   23  13800.0378
# 17     11   24  13600.0259
# 18     11   25  13399.9799
# 19     11   26  13200.0638
# 20     11   27  13399.9799
# 21     11   28  13400.0454
# 22     11   29  13400.0454
# 23     11   30  13600.0914
# 24     12    1  13400.1144
# 25     12    2  14000.0535
# 26     12    3  14000.0535
# 27     12    4   9000.1007
# 28     12    5  14200.0386
# 29     12    6  14000.1225
# 30     12    7  14000.0535
# 31     12    8  14200.0995
# 32     12    9  14600.0616
# ...

# %% [markdown]
# # Q.10. What was the Average 'Quantity Sold' & 'Average Revenue' for each product ?

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Price', 'Quantity', 'Purchase Type',
#        'Payment Method', 'Manager', 'City', 'Revenue', 'month', 'day'],
#       dtype='object')

# %%
df.groupby('Product')['Quantity'].mean().reset_index().rename(columns={"Quantity":'Avg Quantity'})
# Out:
#               Product  Avg Quantity
# 0           Beverages    699.662800
# 1             Burgers    558.121346
# 2  Chicken Sandwiches    214.152308
# 3               Fries    628.124314
# 4       Sides & Other    200.400000

# %%
df.groupby('Product')['Revenue'].mean().reset_index().rename(columns={"Revenue":'Avg Revenue'})
# Out:
#               Product  Avg Revenue
# 0           Beverages  2064.005260
# 1             Burgers  7249.996287
# 2  Chicken Sandwiches  2204.647981
# 3               Fries  2464.201771
# 4       Sides & Other   999.996000
